# %%
import mymodule

x=mymodule.square(4)

print("Square is :",x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mymodule
#       3 x=mymodule.square(4)
#       5 print("Square is :",x)
#
# ModuleNotFoundError: No module named 'mymodule'
